# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
torch.manual_seed(42)
import numpy as np
from collections import defaultdict
from autograd_lib import autograd_lib


from torch.utils.data import DataLoader, TensorDataset

# %%
import os

result_folder = "finalResult_with_hessian4_final1"

if not os.path.exists(result_folder):
    os.mkdir(result_folder)

# %%
Y_func = lambda x : (torch.sin(5*np.pi*x)) /(5*np.pi*x) 
num_of_rows = 300
X= torch.unsqueeze(torch.linspace(-1,1,num_of_rows),dim=1)
Y = Y_func(X)
dataset = TensorDataset(X,Y)
data_loader = DataLoader(dataset,1,shuffle=True)

# %%
plt.figure(figsize=(10,4))
plt.plot(X, Y, color = "red")
plt.title('Non-Linear Function Plotting')
plt.xlabel('Independent varible')
plt.ylabel('Dependent varible')
plt.savefig(result_folder+'/func1_plot.png')

# %%
class MathRegressor(nn.Module):
    def __init__(self, num_hidden=128):
        super().__init__()
        self.regressor = nn.Sequential(
            nn.Linear(1, num_hidden),
            nn.ReLU(),
            nn.Linear(num_hidden, 1)
        )

    def forward(self, x):
        x = self.regressor(x)
        return x
    
    
    
    def training_step(self, batch,loss_fn):
        inputs, targets = batch 
        out = self(inputs)                 # Generate predictions
        loss = loss_fn(out, targets)    # Calculate loss
        return loss
    
    def validation_step(self, batch,loss_fn):
        inputs, targets = batch 
        out = self(inputs)                 # Generate predictions
        loss = loss_fn(out, targets)    # Calculate loss
        return {'val_loss': loss.detach()}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        return {'val_loss': epoch_loss.item()}
    
    def train_step(self, batch,loss_fn):
        inputs, targets = batch 
        out = self(inputs)                 # Generate predictions
        loss = loss_fn(out, targets)    # Calculate loss
        return {'train_loss': loss.detach()}
    
    def train_epoch_end(self, outputs):
        batch_losses = [x['train_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        return {'train_loss': epoch_loss.item()}
    
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}".format(epoch, result['val_loss']))

# %%
def compute_gradient_norm(model, criterion, train, target):
    model.train()
    model.zero_grad()
    output = model(train)
    loss = criterion(output, target)
    loss.backward()

    grads = []
    for p in model.regressor.children():
        if isinstance(p, nn.Linear):
            param_norm = p.weight.grad.norm(2).item()
            grads.append(param_norm)

    grad_mean = np.mean(grads) 

    return grad_mean

def save_activations(layer, A, _):
    activations[layer] = A

def compute_hess(layer, _, B):
    A = activations[layer]
    BA = torch.einsum('nl,ni->nli', B, A) 
    hess[layer] += torch.einsum('nli,nkj->likj', BA, BA)
    
def compute_minimum_ratio(model, criterion, train, target):
    model.zero_grad()
    
    with autograd_lib.module_hook(save_activations):
        output = model(train)
        loss = criterion(output, target)

    with autograd_lib.module_hook(compute_hess):
        autograd_lib.backward_hessian(output, loss='LeastSquares')

    layer_hess = list(hess.values())
    minimum_ratio = []

    for h in layer_hess:
        size = h.shape[0] * h.shape[1]
        h = h.reshape(size, size)
        h_eig = torch.symeig(h).eigenvalues 
        num_greater = torch.sum(h_eig > 0).item()
        minimum_ratio.append(num_greater / len(h_eig))

    ratio_mean = np.mean(minimum_ratio) 

    return ratio_mean

# %%
def get_norm_minimal_ratio(model,criterion):
#     criterion = nn.MSELoss()

    gradient_norm = compute_gradient_norm(model, criterion, X, Y)
    minimum_ratio = compute_minimum_ratio(model, criterion, X, Y)

    print('gradient norm: {}, minimum ratio: {}'.format(gradient_norm, minimum_ratio))
    result = {}
    result["grad_norm"] = gradient_norm
    result["ratio"] = minimum_ratio
    
    return result

# %%
# v2
def evaluate(model,loss_fn, val_loader):
    outputs = [model.validation_step(batch,loss_fn) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def evaluate2(model,loss_fn, train_loader):
    outputs = [model.train_step(batch,loss_fn) for batch in train_loader]
    return model.train_epoch_end(outputs)

def get_grad_norm(model):
    grad_all=0.0
    grad =0
    
    for p in model.parameters():
        if p.grad is not None:
            grad = (p.grad.cpu().data.numpy()**2).sum()
            
        grad_all+=grad
        
    grad_norm=grad_all ** 0.5
    return grad_norm


def fit(epochs, lr, model, data_loader, criterion,opt_func):
    history = []
    comparing_epoch_loss =1000.0
    grad_norm_per_epoch={}
#     autograd_lib.register(model)
#     activations = defaultdict(int)
#     hess = defaultdict(float)
    
#     train_history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
#         grad_norm_per_epoch[epoch] = get_grad_norm(model)
        optimizer.zero_grad()   # clear gradients for next train
    
        if epoch > 900 and epoch%100 ==0:
            print("Comparing result:", (comparing_epoch_loss - result["val_loss"]))
            if (comparing_epoch_loss - result["val_loss"])  < 0.000001:
#                 print("Comparing result:", (comparing_epoch_loss - result["val_loss"]))
                break
            comparing_epoch_loss=result["val_loss"]
        
        # Training Phase 
        prediction = model(X)
        loss = criterion(prediction, Y)     # must be (1. nn output, 2. target)
        loss.backward()         # backpropagation, compute gradients
        
        
        
#             grad_norm_per_epoch[epoch] = get_grad_norm(model)
        
        grad_norm_per_epoch[epoch] = get_norm_minimal_ratio(model,criterion)
        
        
        optimizer.step() 
        
            
            
#             if epoch %100 == 0:
#                 print("grad_norm is :", grad_norm_per_epoch[epoch])
#             if grad_norm_per_epoch[epoch] == 1e-3 :
#                 return history,grad_norm_per_epoch,model
        optimizer.zero_grad()
        # Validation phase
        result = evaluate(model,criterion, data_loader)
        model.epoch_end(epoch, result)
        history.append(result)
        
        if epoch == 900:
            comparing_epoch_loss= result["val_loss"]
        
#         res2 = evaluate2(model,train_loader)
#         train_history.append(res2)
    return history,grad_norm_per_epoch,model

# %%
# initial Parameters
num_of_rows = 300
lr = 0.0004
gamma_lr_scheduler = 0.1 
weight_decay = 1e-4
criterion = nn.MSELoss()
optimizer = torch.optim.Adam
num_epochs =2500
criterion_name = "MSE_LOSS_"
optimizer_name = "ADAM_opt"
filename = criterion_name+ optimizer_name+".png"
grad_norm_name = "_grad_norm_name1_2.png"
result_folder_name = "result3/"

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam
num_epochs =100
criterion_name = "MSE_LOSS_"
optimizer_name = "ADAM_opt"
input_size=1
output_size=1
model= MathRegressor()

# %%
autograd_lib.register(model)
activations = defaultdict(int)
hess = defaultdict(float)

# %%
result_1 = evaluate(model,criterion,data_loader)
result_1
# Out:
# C:\Users\reekm\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# {'val_loss': 0.17534957826137543}

# %%
filename = criterion_name+ optimizer_name+".png"

# %%
train,target = X,Y

# %%
history_1,grad_norm_1,model_1  = fit(num_epochs, lr, model, data_loader, criterion,optimizer)
# Out:
# C:\Users\reekm\AppData\Local\Temp/ipykernel_4148/823926868.py:42: UserWarning: torch.symeig is deprecated in favor of torch.linalg.eigh and will be removed in a future PyTorch release.
# The default behavior has changed from using the upper triangular portion of the matrix by default to using the lower triangular portion.
# L, _ = torch.symeig(A, upper=upper)
# should be replaced with
# L = torch.linalg.eigvalsh(A, UPLO='U' if upper else 'L')
# and
# L, V = torch.symeig(A, eigenvectors=True)
# should be replaced with
# L, V = torch.linalg.eigh(A, UPLO='U' if upper else 'L') (Triggered internally at  ..\aten\src\ATen\native\BatchLinearAlgebra.cpp:2499.)
#   h_eig = torch.symeig(h).eigenvalues
# gradient norm: 1.327238604426384, minimum ratio: 0.6953125
# Epoch [0], val_loss: 0.1842
# gradient norm: 1.3935881406068802, minimum ratio: 0.703125
# Epoch [1], val_loss: 0.1934
# gradient norm: 1.4599925726652145, minimum ratio: 0.73046875
# Epoch [2], val_loss: 0.2031
# gradient norm: 1.5264688581228256, minimum ratio: 0.6953125
# Epoch [3], val_loss: 0.2132
# gradient norm: 1.5929881129413843, minimum ratio: 0.70703125
# Epoch [4], val_loss: 0.2238
# gradient norm: 1.659571759402752, minimum ratio: 0.7109375
# Epoch [5], val_loss: 0.2348
# gradient norm: 1.7262000106275082, minimum ratio: 0.72265625
# Epoch [6], val_loss: 0.2463
# gradient norm: 1.7928792741149664, minimum ratio: 0.73046875
# Epoch [7], val_loss: 0.2581
# gradient norm: 1.8596171606332064, minimum ratio: 0.7109375
# Epoch [8], val_loss: 0.2705
# gradient norm: 1.926396394148469, minimum ratio: 0.734375
# Epoch [9], val_loss: 0.2833
# gradient norm: 1.9932500515133142, minimum ratio: 0.7109375
# Epoch [10], val_loss: 0.2965
# gradient norm: 2.0601299926638603, minimum ratio: 0.734375
# Epoch [11], val_loss: 0.3102
# gradient norm: 2.127047933638096, minimum ratio: 0.71875
# Epoch [12], val_loss: 0.3243
# gradient norm: 2.194052156060934, minimum ratio: 0.72265625
# Epoch [13], val_loss: 0.3389
# gradient norm: 2.261110257357359, minimum ratio: 0.7421875
# Epoch [14], val_loss: 0.3539
# gradient norm: 2.3282157704234123, minimum ratio: 0.73046875
# Epoch [15], val_loss: 0.3693
# gradient norm: 2.3953736759722233, minimum ratio: 0.73828125
# Epoch [16], val_loss: 0.3853
# gradient norm: 2.4626116938889027, minimum ratio: 0.73828125
# Epoch [17], val_loss: 0.4016
# gradient norm: 2.5299160592257977, minimum ratio: 0.75
# Epoch [18], val_loss: 0.4184
# gradient norm: 2.5972795709967613, minimum ratio: 0.7265625
# Epoch [19], val_loss: 0.4357
# gradient norm: 2.6647192277014256, minimum ratio: 0.7109375
# Epoch [20], val_loss: 0.4534
# gradient norm: 2.732231240719557, minimum ratio: 0.734375
# Epoch [21], val_loss: 0.4716
# gradient norm: 2.7998108230531216, minimum ratio: 0.7421875
# Epoch [22], val_loss: 0.4902
# gradient norm: 2.867472004145384, minimum ratio: 0.7109375
# Epoch [23], val_loss: 0.5093
# gradient norm: 2.935264330357313, minimum ratio: 0.73046875
# Epoch [24], val_loss: 0.5288
# gradient norm: 3.0030952468514442, minimum ratio: 0.7265625
# Epoch [25], val_loss: 0.5488
# gradient norm: 3.0710314437747, minimum ratio: 0.75390625
# Epoch [26], val_loss: 0.5693
# gradient norm: 3.139039594680071, minimum ratio: 0.75390625
# Epoch [27], val_loss: 0.5902
# gradient norm: 3.2071255333721638, minimum ratio: 0.76953125
# Epoch [28], val_loss: 0.6115
# gradient norm: 3.2752918004989624, minimum ratio: 0.73046875
# Epoch [29], val_loss: 0.6334
# gradient norm: 3.3435854203999043, minimum ratio: 0.74609375
# Epoch [30], val_loss: 0.6557
# gradient norm: 3.4119677394628525, minimum ratio: 0.73046875
# Epoch [31], val_loss: 0.6784
# gradient norm: 3.480440642684698, minimum ratio: 0.74609375
# Epoch [32], val_loss: 0.7017
# gradient norm: 3.5490057952702045, minimum ratio: 0.7265625
# Epoch [33], val_loss: 0.7254
# gradient norm: 3.6176879554986954, minimum ratio: 0.74609375
# Epoch [34], val_loss: 0.7495
# gradient norm: 3.686480976641178, minimum ratio: 0.73046875
# Epoch [35], val_loss: 0.7741
# gradient norm: 3.7554023414850235, minimum ratio: 0.75
# Epoch [36], val_loss: 0.7993
# gradient norm: 3.824456125497818, minimum ratio: 0.72265625
# Epoch [37], val_loss: 0.8248
# gradient norm: 3.8935701102018356, minimum ratio: 0.75
# Epoch [38], val_loss: 0.8509
# gradient norm: 3.962780736386776, minimum ratio: 0.7265625
# Epoch [39], val_loss: 0.8774
# gradient norm: 4.032128274440765, minimum ratio: 0.7578125
# Epoch [40], val_loss: 0.9044
# gradient norm: 4.101584367454052, minimum ratio: 0.71875
# Epoch [41], val_loss: 0.9319
# gradient norm: 4.1711787804961205, minimum ratio: 0.7265625
# Epoch [42], val_loss: 0.9599
# gradient norm: 4.240863531827927, minimum ratio: 0.74609375
# Epoch [43], val_loss: 0.9883
# gradient norm: 4.3106667175889015, minimum ratio: 0.71875
# Epoch [44], val_loss: 1.0173
# gradient norm: 4.380636379122734, minimum ratio: 0.73046875
# Epoch [45], val_loss: 1.0467
# gradient norm: 4.450730018317699, minimum ratio: 0.72265625
# Epoch [46], val_loss: 1.0766
# gradient norm: 4.5209696516394615, minimum ratio: 0.74609375
# Epoch [47], val_loss: 1.1070
# gradient norm: 4.591308854520321, minimum ratio: 0.734375
# Epoch [48], val_loss: 1.1379
# gradient norm: 4.661831699311733, minimum ratio: 0.73046875
# Epoch [49], val_loss: 1.1692
# gradient norm: 4.73250288516283, minimum ratio: 0.75
# Epoch [50], val_loss: 1.2011
# gradient norm: 4.803282268345356, minimum ratio: 0.7421875
# Epoch [51], val_loss: 1.2335
# gradient norm: 4.874190151691437, minimum ratio: 0.76171875
# Epoch [52], val_loss: 1.2663
# gradient norm: 4.945274583995342, minimum ratio: 0.71484375
# Epoch [53], val_loss: 1.2997
# gradient norm: 5.016456216573715, minimum ratio: 0.75390625
# Epoch [54], val_loss: 1.3336
# gradient norm: 5.087797209620476, minimum ratio: 0.73046875
# Epoch [55], val_loss: 1.3680
# gradient norm: 5.159285239875317, minimum ratio: 0.7578125
# Epoch [56], val_loss: 1.4028
# gradient norm: 5.230969093739986, minimum ratio: 0.7578125
# Epoch [57], val_loss: 1.4382
# gradient norm: 5.302778087556362, minimum ratio: 0.74609375
# Epoch [58], val_loss: 1.4741
# gradient norm: 5.374741934239864, minimum ratio: 0.74609375
# Epoch [59], val_loss: 1.5105
# gradient norm: 5.446906238794327, minimum ratio: 0.7578125
# Epoch [60], val_loss: 1.5475
# gradient norm: 5.51916266977787, minimum ratio: 0.72265625
# Epoch [61], val_loss: 1.5849
# gradient norm: 5.591589652001858, minimum ratio: 0.74609375
# Epoch [62], val_loss: 1.6229
# gradient norm: 5.664177976548672, minimum ratio: 0.73046875
# Epoch [63], val_loss: 1.6613
# gradient norm: 5.736862346529961, minimum ratio: 0.734375
# Epoch [64], val_loss: 1.7003
# gradient norm: 5.809846296906471, minimum ratio: 0.734375
# Epoch [65], val_loss: 1.7398
# gradient norm: 5.882927402853966, minimum ratio: 0.74609375
# Epoch [66], val_loss: 1.7799
# gradient norm: 5.956145033240318, minimum ratio: 0.765625
# Epoch [67], val_loss: 1.8205
# gradient norm: 6.029555991292, minimum ratio: 0.7421875
# Epoch [68], val_loss: 1.8616
# gradient norm: 6.103238001465797, minimum ratio: 0.73046875
# Epoch [69], val_loss: 1.9032
# gradient norm: 6.1770768612623215, minimum ratio: 0.74609375
# Epoch [70], val_loss: 1.9454
# gradient norm: 6.251055270433426, minimum ratio: 0.73828125
# Epoch [71], val_loss: 1.9882
# gradient norm: 6.3252513855695724, minimum ratio: 0.7421875
# Epoch [72], val_loss: 2.0314
# gradient norm: 6.399600878357887, minimum ratio: 0.74609375
# Epoch [73], val_loss: 2.0752
# gradient norm: 6.474167615175247, minimum ratio: 0.72265625
# Epoch [74], val_loss: 2.1196
# gradient norm: 6.548886686563492, minimum ratio: 0.75390625
# Epoch [75], val_loss: 2.1645
# gradient norm: 6.623832628130913, minimum ratio: 0.7421875
# Epoch [76], val_loss: 2.2099
# gradient norm: 6.698971256613731, minimum ratio: 0.73828125
# Epoch [77], val_loss: 2.2560
# gradient norm: 6.774255603551865, minimum ratio: 0.75
# Epoch [78], val_loss: 2.3025
# gradient norm: 6.849714204668999, minimum ratio: 0.73828125
# Epoch [79], val_loss: 2.3496
# gradient norm: 6.92534638941288, minimum ratio: 0.75390625
# Epoch [80], val_loss: 2.3973
# gradient norm: 7.001204639673233, minimum ratio: 0.765625
# Epoch [81], val_loss: 2.4456
# gradient norm: 7.077354371547699, minimum ratio: 0.7421875
# Epoch [82], val_loss: 2.4944
# gradient norm: 7.153629243373871, minimum ratio: 0.734375
# Epoch [83], val_loss: 2.5438
# gradient norm: 7.230184003710747, minimum ratio: 0.7265625
# Epoch [84], val_loss: 2.5937
# gradient norm: 7.30691097676754, minimum ratio: 0.75
# Epoch [85], val_loss: 2.6443
# gradient norm: 7.383737698197365, minimum ratio: 0.73046875
# Epoch [86], val_loss: 2.6954
# gradient norm: 7.460872128605843, minimum ratio: 0.73828125
# Epoch [87], val_loss: 2.7471
# gradient norm: 7.5382606983184814, minimum ratio: 0.734375
# Epoch [88], val_loss: 2.7993
# gradient norm: 7.615776062011719, minimum ratio: 0.73828125
# Epoch [89], val_loss: 2.8522
# gradient norm: 7.693520322442055, minimum ratio: 0.75
# Epoch [90], val_loss: 2.9056
# gradient norm: 7.771449968218803, minimum ratio: 0.7265625
# Epoch [91], val_loss: 2.9597
# gradient norm: 7.84968689084053, minimum ratio: 0.7421875
# Epoch [92], val_loss: 3.0143
# gradient norm: 7.928160980343819, minimum ratio: 0.76171875
# Epoch [93], val_loss: 3.0696
# gradient norm: 8.006814152002335, minimum ratio: 0.74609375
# Epoch [94], val_loss: 3.1254
# gradient norm: 8.085706412792206, minimum ratio: 0.76953125
# Epoch [95], val_loss: 3.1818
# gradient norm: 8.16487105190754, minimum ratio: 0.7421875
# Epoch [96], val_loss: 3.2389
# gradient norm: 8.244284749031067, minimum ratio: 0.73828125
# Epoch [97], val_loss: 3.2966
# gradient norm: 8.323758631944656, minimum ratio: 0.7578125
# Epoch [98], val_loss: 3.3548
# gradient norm: 8.403550162911415, minimum ratio: 0.73046875
# Epoch [99], val_loss: 3.4137

# %%
grad_norm_1
# Out:
# {0: {'grad_norm': 1.327238604426384, 'ratio': 0.6953125},
#  1: {'grad_norm': 1.3935881406068802, 'ratio': 0.703125},
#  2: {'grad_norm': 1.4599925726652145, 'ratio': 0.73046875},
#  3: {'grad_norm': 1.5264688581228256, 'ratio': 0.6953125},
#  4: {'grad_norm': 1.5929881129413843, 'ratio': 0.70703125},
#  5: {'grad_norm': 1.659571759402752, 'ratio': 0.7109375},
#  6: {'grad_norm': 1.7262000106275082, 'ratio': 0.72265625},
#  7: {'grad_norm': 1.7928792741149664, 'ratio': 0.73046875},
#  8: {'grad_norm': 1.8596171606332064, 'ratio': 0.7109375},
#  9: {'grad_norm': 1.926396394148469, 'ratio': 0.734375},
#  10: {'grad_norm': 1.9932500515133142, 'ratio': 0.7109375},
#  11: {'grad_norm': 2.0601299926638603, 'ratio': 0.734375},
#  12: {'grad_norm': 2.127047933638096, 'ratio': 0.71875},
#  13: {'grad_norm': 2.194052156060934, 'ratio': 0.72265625},
#  14: {'grad_norm': 2.261110257357359, 'ratio': 0.7421875},
#  15: {'grad_norm': 2.3282157704234123, 'ratio': 0.73046875},
#  16: {'grad_norm': 2.3953736759722233, 'ratio': 0.73828125},
#  17: {'grad_norm': 2.4626116938889027, 'ratio': 0.73828125},
#  18: {'grad_norm': 2.5299160592257977, 'ratio': 0.75},
#  19: {'grad_norm': 2.5972795709967613, 'ratio': 0.7265625},
#  20: {'grad_norm': 2.6647192277014256, 'ratio': 0.7109375},
#  21: {'grad_norm': 2.732231240719557, 'ratio': 0.734375},
#  22: {'grad_norm': 2.7998108230531216, 'ratio': 0.7421875},
#  23: {'grad_norm': 2.867472004145384, 'ratio': 0.7109375},
#  24: {'grad_norm': 2.935264330357313, 'ratio': 0.73046875},
#  25: {'grad_norm': 3.0030952468514442, 'ratio': 0.7265625},
#  26: {'grad_norm': 3.0710314437747, 'ratio': 0.75390625},
#  27: {'grad_norm': 3.139039594680071, 'ratio': 0.75390625},
#  28: {'grad_norm': 3.2071255333721638, 'ratio': 0.76953125},
#  29: {'grad_norm': 3.2752918004989624, 'ratio': 0.73046875},
#  30: {'grad_norm': 3.3435854203999043, 'ratio': 0.74609375},
#  31: {'grad_norm': 3.4119677394628525, 'ratio': 0.73046875},
#  32: {'grad_norm': 3.480440642684698, 'ratio': 0.74609375},
#  33: {'grad_norm': 3.5490057952702045, 'ratio': 0.7265625},
#  34: {'grad_norm': 3.6176879554986954, 'ratio': 0.74609375},
#  35: {'grad_norm': 3.686480976641178, 'ratio': 0.73046875},
#  36: {'grad_norm': 3.7554023414850235, 'ratio': 0.75},
#  37: {'grad_norm': 3.824456125497818, 'ratio': 0.72265625},
#  38: {'grad_norm': 3.8935701102018356, 'ratio': 0.75},
#  39: {'grad_norm': 3.962780736386776, 'ratio': 0.7265625},
#  40: {'grad_norm': 4.032128274440765, 'ratio': 0.7578125},
#  41: {'grad_norm': 4.101584367454052, 'ratio': 0.71875},
#  42: {'grad_norm': 4.1711787804961205, 'ratio': 0.7265625},
#  43: {'grad_norm': 4.240863531827927, 'ratio': 0.74609375},
#  44: {'grad_norm': 4.3106667175889015, 'ratio': 0.71875},
#  45: {'grad_norm': 4.380636379122734, 'ratio': 0.73046875},
#  46: {'grad_norm': 4.450730018317699, 'ratio': 0.72265625},
#  47: {'grad_norm': 4.5209696516394615, 'ratio': 0.74609375},
#  48: {'grad_norm': 4.591308854520321, 'ratio': 0.734375},
#  49: {'grad_norm': 4.661831699311733, 'ratio': 0.73046875},
#  50: {'grad_norm': 4.73250288516283, 'ratio': 0.75},
#  51: {'grad_norm': 4.803282268345356, 'ratio': 0.7421875},
#  52: {'grad_norm': 4.874190151691437, 'ratio': 0.76171875},
#  53: {'grad_norm': 4.945274583995342, 'ratio': 0.71484375},
#  54: {'grad_norm': 5.016456216573715, 'ratio': 0.75390625},
#  55: {'grad_norm': 5.087797209620476, 'ratio': 0.73046875},
#  56: {'grad_norm': 5.159285239875317, 'ratio': 0.7578125},
#  57: {'grad_norm': 5.230969093739986, 'ratio': 0.7578125},
#  58: {'grad_norm': 5.302778087556362, 'ratio': 0.74609375},
#  59: {'grad_norm': 5.374741934239864, 'ratio': 0.74609375},
#  60: {'grad_norm': 5.446906238794327, 'ratio': 0.7578125},
#  61: {'grad_norm': 5.51916266977787, 'ratio': 0.72265625},
#  62: {'grad_norm': 5.591589652001858, 'ratio': 0.74609375},
#  63: {'grad_norm': 5.664177976548672, 'ratio': 0.73046875},
#  64: {'grad_norm': 5.736862346529961, 'ratio': 0.734375},
#  65: {'grad_norm': 5.809846296906471, 'ratio': 0.734375},
#  66: {'grad_norm': 5.882927402853966, 'ratio': 0.74609375},
#  67: {'grad_norm': 5.956145033240318, 'ratio': 0.765625},
#  68: {'grad_norm': 6.029555991292, 'ratio': 0.7421875},
#  69: {'grad_norm': 6.103238001465797, 'ratio': 0.73046875},
#  70: {'grad_norm': 6.1770768612623215, 'ratio': 0.74609375},
#  71: {'grad_norm': 6.251055270433426, 'ratio': 0.73828125},
#  72: {'grad_norm': 6.3252513855695724, 'ratio': 0.7421875},
#  73: {'grad_norm': 6.399600878357887, 'ratio': 0.74609375},
#  74: {'grad_norm': 6.474167615175247, 'ratio': 0.72265625},
#  75: {'grad_norm': 6.548886686563492, 'ratio': 0.75390625},
#  76: {'grad_norm': 6.623832628130913, 'ratio': 0.7421875},
#  77: {'grad_norm': 6.698971256613731, 'ratio': 0.73828125},
#  78: {'grad_norm': 6.774255603551865, 'ratio': 0.75},
#  79: {'grad_norm': 6.849714204668999, 'ratio': 0.73828125},
#  80: {'grad_norm': 6.92534638941288, 'ratio': 0.75390625},
#  81: {'grad_norm': 7.001204639673233, 'ratio': 0.765625},
#  82: {'grad_norm': 7.077354371547699, 'ratio': 0.7421875},
#  83: {'grad_norm': 7.153629243373871, 'ratio': 0.734375},
#  84: {'grad_norm': 7.230184003710747, 'ratio': 0.7265625},
#  85: {'grad_norm': 7.30691097676754, 'ratio': 0.75},
#  86: {'grad_norm': 7.383737698197365, 'ratio': 0.73046875},
#  87: {'grad_norm': 7.460872128605843, 'ratio': 0.73828125},
#  88: {'grad_norm': 7.5382606983184814, 'ratio': 0.734375},
#  89: {'grad_norm': 7.615776062011719, 'ratio': 0.73828125},
#  90: {'grad_norm': 7.693520322442055, 'ratio': 0.75},
#  91: {'grad_norm': 7.771449968218803, 'ratio': 0.7265625},
#  92: {'grad_norm': 7.84968689084053, 'ratio': 0.7421875},
#  93: {'grad_norm': 7.928160980343819, 'ratio': 0.76171875},
#  94: {'grad_norm': 8.006814152002335, 'ratio': 0.74609375},
#  95: {'grad_norm': 8.085706412792206, 'ratio': 0.76953125},
#  96: {'grad_norm': 8.16487105190754, 'ratio': 0.7421875},
#  97: {'grad_norm': 8.244284749031067, 'ratio': 0.73828125},
#  98: {'grad_norm': 8.323758631944656, 'ratio': 0.7578125},
#  99: {'grad_norm': 8.403550162911415, 'ratio': 0.73046875}}

# %%
val_losses_1 = [r['val_loss'] for r in history_1]

# %%
len(val_losses_1)
# Out:
# 100

# %%
loss = []
ratio =[]
for i in grad_norm_1.keys():
    val_1 = grad_norm_1[i]
#     if val_1['grad_norm'] == 0:
    loss.append(val_losses_1[i])
    ratio.append(val_1['ratio'])

# %%
# minimal_ratio_eps = [i['ratio'] for i in grad_norm_1.values() ]

# %%
plt.figure(figsize=(10,10))
plt.scatter(ratio,loss)
plt.xlabel('minimal ratio')
plt.ylabel('loss')
plt.title('loss_vs_minimal ratio');
plt.plot()
plt.savefig("loss_vs_minimal ratio.png")
